# %%
import pandas as pd

stats = pd.read_csv("P4-Demographic-Data.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,4
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution
vis1 = sns.distplot(stats['InternetUsers'], bins = 30)

# %%
#Boxplots:

vis2 = sns.boxplot(data=stats, x="IncomeGroup", y="BirthRate")

# %%
#seaborn gallery: https://seaborn.pydata.org/examples/index.html

# %%
vis3 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", fit_reg=False, size=8)

# %%
#Distribution
vis4 = sns.distplot(stats['BirthRate'], bins = 30)

# %%
vis5 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", fit_reg=False, size=8, hue='IncomeGroup')

# %%
##### keyword arguments in python (advance tutorial)

# %%
#Marker size: scatter_kws is a matplotlib wrapper

vis6 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", fit_reg=False, size=8, hue='IncomeGroup', scatter_kws={"s":100})

# %%
#### HomeWork
